# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
df_tracks = pd.read_csv(os.path.join(os.getcwd(), "fma_metadata", "tracks.csv"), index_col=0, header=[0, 1])
df_tracks.head()
# Out:
#             album                                                     \
#          comments         date_created        date_released engineer
# track_id
# 2               0  2008-11-26 01:44:45  2009-01-05 00:00:00      NaN
# 3               0  2008-11-26 01:44:45  2009-01-05 00:00:00      NaN
# 5               0  2008-11-26 01:44:45  2009-01-05 00:00:00      NaN
# 10              0  2008-11-26 01:45:08  2008-02-06 00:00:00      NaN
# 20              0  2008-11-26 01:45:05  2009-01-06 00:00:00      NaN
#
#                                                                           \
#          favorites id                                information listens
# track_id
# 2                4  1                                    <p></p>    6073
# 3                4  1                                    <p></p>    6073
# 5                4  1                                    <p></p>    6073
# 10               4  6                                        NaN   47632
# 20               2  4  <p> "spiritual songs" from Nicky Cook</p>    2710
#
#                         ...       track                         \
#          producer tags  ... information interest language_code
# track_id                ...
# 2             NaN   []  ...         NaN     4656            en
# 3             NaN   []  ...         NaN     1470            en
# 5             NaN   []  ...         NaN     1933            en
# 10            NaN   []  ...         NaN    54881            en
# 20            NaN   []  ...         NaN      978            en
#
#                                                                               \
#                                                     license listens lyricist
# track_id
# 2         Attribution-NonCommercial-ShareAlike 3.0 Inter...    1293      NaN
# 3         Attribution-NonCommercial-ShareAlike 3.0 Inter...     514      NaN
# 5         Attribution-NonCommercial-ShareAlike 3.0 Inter...    1151      NaN
# 10        Attribution-NonCommercial-NoDerivatives (aka M...   50135      NaN
# 20        Attribution-NonCommercial-NoDerivatives (aka M...     361      NaN
#
#
#          number publisher tags            title
# track_id
# 2             3       NaN   []             Food
# 3             4       NaN   []     Electric Ave
# 5             6       NaN   []       This World
# 10            1       NaN   []          Freeway
# 20            3       NaN   []  Spiritual Level
#
# [5 rows x 52 columns]

# %%
keep_tracks = df_tracks[df_tracks[('set', 'subset')] == 'small']
df_tracks = keep_tracks[[('track', 'genre_top'), ('set', 'split')]].reset_index()
df_tracks.columns = ['track_id', 'genre_top', 'split']

# %%
df_tracks.head()
# Out:
#    track_id genre_top     split
# 0         2   Hip-Hop  training
# 1         5   Hip-Hop  training
# 2        10       Pop  training
# 3       140      Folk  training
# 4       141      Folk  training

# %%
df_tracks.value_counts('split')
# Out:
# split
# training      6400
# validation     800
# test           800
# Name: count, dtype: int64

# %%
df_tracks.shape
# Out:
# (8000, 3)

# %%
df_tracks["genre_top"].value_counts()
# Out:
# genre_top
# Hip-Hop          1000
# Pop              1000
# Folk             1000
# Experimental     1000
# Rock             1000
# International    1000
# Electronic       1000
# Instrumental     1000
# Name: count, dtype: int64

# %%
# df = pd.read_csv(os.path.join(os.getcwd(), "fma_metadata", "features_small_mniej_cech.csv"))
df = pd.read_csv(os.path.join(os.getcwd(), "fma_metadata", "features.csv"), header=[0, 1, 2], index_col=0)
# Out:
# feature    chroma_cens                                                    \
# statistics    kurtosis
# number              01        02        03        04        05        06
# track_id
# 2             7.180653  5.230309  0.249321  1.347620  1.482478  0.531371
# 3             1.888963  0.760539  0.345297  2.295201  1.654031  0.067592
# 5             0.527563 -0.077654 -0.279610  0.685883  1.937570  0.880839
# 10            3.702245 -0.291193  2.196742 -0.234449  1.367364  0.998411
# 20           -0.193837 -0.198527  0.201546  0.258556  0.775204  0.084794
#
# feature                                             ...   tonnetz            \
# statistics                                          ...       std
# number            07        08        09        10  ...        04        05
# track_id                                            ...
# 2           1.481593  2.691455  0.866868  1.341231  ...  0.054125  0.012226
# 3           1.366848  1.054094  0.108103  0.619185  ...  0.063831  0.014212
# 5          -0.923192 -0.927232  0.666617  1.038546  ...  0.040730  0.012691
# 10          1.770694  1.604566  0.521217  1.982386  ...  0.074358  0.017952
# 20         -0.289294 -0.816410  0.043851 -0.804761  ...  0.095003  0.022492
#
# feature                     zcr                                          \
# statistics             kurtosis       max      mean    median       min
# number            06         01        01        01        01        01
# track_id
# 2           0.012111   5.758890  0.459473  0.085629  0.071289  0.000000
# 3           0.017740   2.824694  0.466309  0.084578  0.063965  0.000000
# 5           0.014759   6.808415  0.375000  0.053114  0.041504  0.000000
# 10          0.013921  21.434212  0.452148  0.077515  0.071777  0.000000
# 20          0.021355  16.669037  0.469727  0.047225  0.040039  0.000977
#
# feature
# statistics      skew       std
# number            01        01
# track_id
# 2           2.089872  0.061448
# 3           1.716724  0.069330
# 5           2.193303  0.044861
# 10          3.542325  0.040800
# 20          3.189831  0.030993
#
# [5 rows x 518 columns]

# %%
df1 = df.copy()
df1.head()
df1.columns = ['_'.join(col) for col in df.columns]
df1.head()
# Out:
#           chroma_cens_kurtosis_01  chroma_cens_kurtosis_02  \
# track_id
# 2                        7.180653                 5.230309
# 3                        1.888963                 0.760539
# 5                        0.527563                -0.077654
# 10                       3.702245                -0.291193
# 20                      -0.193837                -0.198527
#
#           chroma_cens_kurtosis_03  chroma_cens_kurtosis_04  \
# track_id
# 2                        0.249321                 1.347620
# 3                        0.345297                 2.295201
# 5                       -0.279610                 0.685883
# 10                       2.196742                -0.234449
# 20                       0.201546                 0.258556
#
#           chroma_cens_kurtosis_05  chroma_cens_kurtosis_06  \
# track_id
# 2                        1.482478                 0.531371
# 3                        1.654031                 0.067592
# 5                        1.937570                 0.880839
# 10                       1.367364                 0.998411
# 20                       0.775204                 0.084794
#
#           chroma_cens_kurtosis_07  chroma_cens_kurtosis_08  \
# track_id
# 2                        1.481593                 2.691455
# 3                        1.366848                 1.054094
# 5                       -0.923192                -0.927232
# 10                       1.770694                 1.604566
# 20                      -0.289294                -0.816410
#
#           chroma_cens_kurtosis_09  chroma_cens_kurtosis_10  ...  \
# track_id                                                    ...
# 2                        0.866868                 1.341231  ...
# 3                        0.108103                 0.619185  ...
# 5                        0.666617                 1.038546  ...
# 10                       0.521217                 1.982386  ...
# 20                       0.043851                -0.804761  ...
#
#           tonnetz_std_04  tonnetz_std_05  tonnetz_std_06  zcr_kurtosis_01  \
# track_id
# 2               0.054125        0.012226        0.012111         5.758890
# 3               0.063831        0.014212        0.017740         2.824694
# 5               0.040730        0.012691        0.014759         6.808415
# 10              0.074358        0.017952        0.013921        21.434212
# 20              0.095003        0.022492        0.021355        16.669037
#
#           zcr_max_01  zcr_mean_01  zcr_median_01  zcr_min_01  zcr_skew_01  \
# track_id
# 2           0.459473     0.085629       0.071289    0.000000     2.089872
# 3           0.466309     0.084578       0.063965    0.000000     1.716724
# 5           0.375000     0.053114       0.041504    0.000000     2.193303
# 10          0.452148     0.077515       0.071777    0.000000     3.542325
# 20          0.469727     0.047225       0.040039    0.000977     3.189831
#
#           zcr_std_01
# track_id
# 2           0.061448
# 3           0.069330
# 5           0.044861
# 10          0.040800
# 20          0.030993
#
# [5 rows x 518 columns]

# %%
df_tracks.head()
# Out:
#    track_id genre_top     split
# 0         2   Hip-Hop  training
# 1         5   Hip-Hop  training
# 2        10       Pop  training
# 3       140      Folk  training
# 4       141      Folk  training

# %%
df1 = df1.copy()
df1 = df1.merge(df_tracks[['track_id', 'genre_top', 'split']], on='track_id', how='right')

# %%
df1.head()
# Out:
#    track_id  chroma_cens_kurtosis_01  chroma_cens_kurtosis_02  \
# 0         2                 7.180653                 5.230309
# 1         5                 0.527563                -0.077654
# 2        10                 3.702245                -0.291193
# 3       140                 0.533579                -0.623885
# 4       141                 0.172898                -0.284804
#
#    chroma_cens_kurtosis_03  chroma_cens_kurtosis_04  chroma_cens_kurtosis_05  \
# 0                 0.249321                 1.347620                 1.482478
# 1                -0.279610                 0.685883                 1.937570
# 2                 2.196742                -0.234449                 1.367364
# 3                -1.086205                -1.081079                -0.765151
# 4                -1.169662                -1.062855                -0.706868
#
#    chroma_cens_kurtosis_06  chroma_cens_kurtosis_07  chroma_cens_kurtosis_08  \
# 0                 0.531371                 1.481593                 2.691455
# 1                 0.880839                -0.923192                -0.927232
# 2                 0.998411                 1.770694                 1.604566
# 3                -0.072282                -0.882913                -0.582376
# 4                -0.708281                -0.204884                 0.023624
#
#    chroma_cens_kurtosis_09  ...  tonnetz_std_06  zcr_kurtosis_01  zcr_max_01  \
# 0                 0.866868  ...        0.012111         5.758890    0.459473
# 1                 0.666617  ...        0.014759         6.808415    0.375000
# 2                 0.521217  ...        0.013921        21.434212    0.452148
# 3                -0.884749  ...        0.025946        11.052547    0.379395
# 4                -0.642770  ...        0.032111        32.994659    0.415527
#
#    zcr_mean_01  zcr_median_01  zcr_min_01  zcr_skew_01  zcr_std_01  genre_top  \
# 0     0.085629       0.071289    0.000000     2.089872    0.061448    Hip-Hop
# 1     0.053114       0.041504    0.000000     2.193303    0.044861    Hip-Hop
# 2     0.077515       0.071777    0.000000     3.542325    0.040800        Pop
# 3     0.052379       0.036621    0.001953     3.143968    0.057712       Folk
# 4     0.040267       0.034668    0.002930     4.204097    0.028665       Folk
#
#       split
# 0  training
# 1  training
# 2  training
# 3  training
# 4  training
#
# [5 rows x 521 columns]

# %%
statistics = ['mean', 'std']

feature_columns = []

feature_sizes = dict(
        chroma_stft=12,
        mfcc=20, rmse=1, zcr=1,
        spectral_centroid=1
    )

for feature, size in feature_sizes.items():
    for stat in statistics:
        for i in range(1, size + 1):
            col = f"{feature}_{stat}_{i:02d}"
            feature_columns.append(col)

feature_columns.extend(["track_id", "genre_top", "split"])
print(len(feature_columns))
print(feature_columns)
# Out:
# 73
# ['chroma_stft_mean_01', 'chroma_stft_mean_02', 'chroma_stft_mean_03', 'chroma_stft_mean_04', 'chroma_stft_mean_05', 'chroma_stft_mean_06', 'chroma_stft_mean_07', 'chroma_stft_mean_08', 'chroma_stft_mean_09', 'chroma_stft_mean_10', 'chroma_stft_mean_11', 'chroma_stft_mean_12', 'chroma_stft_std_01', 'chroma_stft_std_02', 'chroma_stft_std_03', 'chroma_stft_std_04', 'chroma_stft_std_05', 'chroma_stft_std_06', 'chroma_stft_std_07', 'chroma_stft_std_08', 'chroma_stft_std_09', 'chroma_stft_std_10', 'chroma_stft_std_11', 'chroma_stft_std_12', 'mfcc_mean_01', 'mfcc_mean_02', 'mfcc_mean_03', 'mfcc_mean_04', 'mfcc_mean_05', 'mfcc_mean_06', 'mfcc_mean_07', 'mfcc_mean_08', 'mfcc_mean_09', 'mfcc_mean_10', 'mfcc_mean_11', 'mfcc_mean_12', 'mfcc_mean_13', 'mfcc_mean_14', 'mfcc_mean_15', 'mfcc_mean_16', 'mfcc_mean_17', 'mfcc_mean_18', 'mfcc_mean_19', 'mfcc_mean_20', 'mfcc_std_01', 'mfcc_std_02', 'mfcc_std_03', 'mfcc_std_04', 'mfcc_std_05', 'mfcc_std_06', 'mfcc_std_07', 'mfcc_std_08', 'mfcc_std_09', 'mfcc_std_10', 'mfcc_std_11', 'mfcc_std_12', 'mfcc_std_13', 'mfcc_std_14', 'mfcc_std_15', 'mfcc_std_16', 'mfcc_std_17', 'mfcc_std_18', 'mfcc_std_19', 'mfcc_std_20', 'rmse_mean_01', 'rmse_std_01', 'zcr_mean_01', 'zcr_std_01', 'spectral_centroid_mean_01', 'spectral_centroid_std_01', 'track_id', 'genre_top', 'split']

# %%
df1 = df1[feature_columns]
df2 = df1.copy()

# %%
col = df2.pop('genre_top')
df2.insert(1, 'genre', col)
col_id = 'track_id'
df2 = df2[[col_id] + [c for c in df2.columns if c != col_id]]
df2.head()
# Out:
#    track_id  chroma_stft_mean_01    genre  chroma_stft_mean_02  \
# 0         2             0.696063  Hip-Hop             0.447832
# 1         5             0.481160  Hip-Hop             0.658690
# 2        10             0.388109      Pop             0.655152
# 3       140             0.375882     Folk             0.462594
# 4       141             0.231164     Folk             0.197846
#
#    chroma_stft_mean_03  chroma_stft_mean_04  chroma_stft_mean_05  \
# 0             0.355580             0.349723             0.340518
# 1             0.451551             0.368825             0.334513
# 2             0.452144             0.440090             0.355828
# 3             0.549908             0.427090             0.474710
# 4             0.265860             0.247411             0.351850
#
#    chroma_stft_mean_06  chroma_stft_mean_07  chroma_stft_mean_08  ...  \
# 0             0.266161             0.291201             0.430514  ...
# 1             0.324101             0.340564             0.354422  ...
# 2             0.410883             0.611984             0.421226  ...
# 3             0.429138             0.332495             0.349981  ...
# 4             0.434773             0.305727             0.312977  ...
#
#    mfcc_std_18  mfcc_std_19  mfcc_std_20  rmse_mean_01  rmse_std_01  \
# 0     7.246555     7.077188     7.391859      3.188761     2.536809
# 1     7.539753     8.452527     7.334442      3.251386     2.585286
# 2     6.928591     6.430473     6.186294      3.893810     2.004721
# 3     7.734456     7.807103     7.986255      2.953848     1.808950
# 4     8.341757     8.572934     9.351485      2.576761     2.069247
#
#    zcr_mean_01  zcr_std_01  spectral_centroid_mean_01  \
# 0     0.085629    0.061448                1639.583252
# 1     0.053114    0.044861                1292.958130
# 2     0.077515    0.040800                1360.028687
# 3     0.052379    0.057712                1232.633789
# 4     0.040267    0.028665                 941.244141
#
#    spectral_centroid_std_01     split
# 0                719.770508  training
# 1                665.319275  training
# 2                668.700806  training
# 3                726.773254  training
# 4                442.332092  training
#
# [5 rows x 73 columns]

# %% [markdown]
# # statystyka

# %%
miss = df2.isnull().sum()

# %%
miss.sort_values()
# Out:
# track_id                     0
# chroma_stft_mean_01          0
# genre                        0
# chroma_stft_mean_02          0
# chroma_stft_mean_03          0
#                             ..
# zcr_mean_01                  0
# zcr_std_01                   0
# spectral_centroid_mean_01    0
# spectral_centroid_std_01     0
# split                        0
# Length: 73, dtype: int64

# %%
# handling missing values - mean in class (genre id)
numeric_cols = df2.select_dtypes(include=[np.number]).columns
df2[numeric_cols] = df2[numeric_cols].fillna(
    df2.groupby('genre')[numeric_cols].transform('mean')
)

# %%
df2.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 73 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   track_id                   8000 non-null   int64
#  1   chroma_stft_mean_01        8000 non-null   float64
#  2   genre                      8000 non-null   str
#  3   chroma_stft_mean_02        8000 non-null   float64
#  4   chroma_stft_mean_03        8000 non-null   float64
#  5   chroma_stft_mean_04        8000 non-null   float64
#  6   chroma_stft_mean_05        8000 non-null   float64
#  7   chroma_stft_mean_06        8000 non-null   float64
#  8   chroma_stft_mean_07        8000 non-null   float64
#  9   chroma_stft_mean_08        8000 non-null   float64
#  10  chroma_stft_mean_09        8000 non-null   float64
#  11  chroma_stft_mean_10        8000 non-null   float64
#  12  chroma_stft_mean_11        8000 non-null   float64
#  13  chroma_stft_mean_12        8000 non-null   float64
#  14  chroma_stft_std_01         8000 non-null   float64
#  15  chroma_stft_std_02         8000 non-null   float64
#  16  chroma_stft_std_03         8000 non-null   float64
#  17  chroma_stft_std_04         8000 non-null   float64
#  18  chroma_stft_std_05         8000 non-null   float64
#  19  chroma_stft_std_06         8000 non-null   float64
#  20  chroma_stft_std_07         8000 non-null   float64
#  21  chroma_stft_std_08         8000 non-null   float64
#  22  chroma_stft_std_09         8000 non-null   float64
#  23  chroma_stft_std_10         8000 non-null   float64
#  24  chroma_stft_std_11         8000 non-null   float64
#  25  chroma_stft_std_12         8000 non-null   float64
#  26  mfcc_mean_01               8000 non-null   float64
#  27  mfcc_mean_02               8000 non-null   float64
#  28  mfcc_mean_03               8000 non-null   float64
#  29  mfcc_mean_04               8000 non-null   float64
#  30  mfcc_mean_05               8000 non-null   float64
#  31  mfcc_mean_06               8000 non-null   float64
#  32  mfcc_mean_07               8000 non-null   float64
#  33  mfcc_mean_08               8000 non-null   float64
#  34  mfcc_mean_09               8000 non-null   float64
#  35  mfcc_mean_10               8000 non-null   float64
#  36  mfcc_mean_11               8000 non-null   float64
#  37  mfcc_mean_12               8000 non-null   float64
#  38  mfcc_mean_13               8000 non-null   float64
#  39  mfcc_mean_14               8000 non-null   float64
#  40  mfcc_mean_15               8000 non-null   float64
#  41  mfcc_mean_16               8000 non-null   float64
#  42  mfcc_mean_17               8000 non-null   float64
#  43  mfcc_mean_18               8000 non-null   float64
#  44  mfcc_mean_19               8000 non-null   float64
#  45  mfcc_mean_20               8000 non-null   float64
#  46  mfcc_std_01                8000 non-null   float64
#  47  mfcc_std_02                8000 non-null   float64
#  48  mfcc_std_03                8000 non-null   float64
#  49  mfcc_std_04                8000 non-null   float64
#  50  mfcc_std_05                8000 non-null   float64
#  51  mfcc_std_06                8000 non-null   float64
#  52  mfcc_std_07                8000 non-null   float64
#  53  mfcc_std_08                8000 non-null   float64
#  54  mfcc_std_09                8000 non-null   float64
#  55  mfcc_std_10                8000 non-null   float64
#  56  mfcc_std_11                8000 non-null   float64
#  57  mfcc_std_12                8000 non-null   float64
#  58  mfcc_std_13                8000 non-null   float64
#  59  mfcc_std_14                8000 non-null   float64
#  60  mfcc_std_15                8000 non-null   float64
#  61  mfcc_std_16                8000 non-null   float64
#  62  mfcc_std_17                8000 non-null   float64
#  63  mfcc_std_18                8000 non-null   float64
#  64  mfcc_std_19                8000 non-null   float64
#  65  mfcc_std_20                8000 non-null   float64
#  66  rmse_mean_01               8000 non-null   float64
#  67  rmse_std_01                8000 non-null   float64
#  68  zcr_mean_01                8000 non-null   float64
#  69  zcr_std_01                 8000 non-null   float64
#  70  spectral_centroid_mean_01  8000 non-null   float64
#  71  spectral_centroid_std_01   8000 non-null   float64
#  72  split                      8000 non-null   str
# dtypes: float64(70), int64(1), str(2)
# memory usage: 4.5 MB

# %%
df2.describe()
# Out:
#             track_id  chroma_stft_mean_01  chroma_stft_mean_02  \
# count    8000.000000          8000.000000          8000.000000
# mean    84126.770125             0.450212             0.435966
# std     43297.426287             0.128222             0.121855
# min         2.000000             0.034320             0.033964
# 25%     49063.500000             0.361290             0.352420
# 50%     89281.000000             0.449135             0.432833
# 75%    122545.000000             0.535078             0.512857
# max    155066.000000             0.998968             0.983143
#
#        chroma_stft_mean_03  chroma_stft_mean_04  chroma_stft_mean_05  \
# count          8000.000000          8000.000000          8000.000000
# mean              0.454001             0.439165             0.454843
# std               0.126442             0.124657             0.126565
# min               0.033757             0.035419             0.036157
# 25%               0.368596             0.354914             0.368241
# 50%               0.454478             0.438355             0.456402
# 75%               0.536964             0.518903             0.538346
# max               0.945509             0.952649             0.933879
#
#        chroma_stft_mean_06  chroma_stft_mean_07  chroma_stft_mean_08  \
# count          8000.000000          8000.000000          8000.000000
# mean              0.434449             0.426792             0.443754
# std               0.125996             0.118001             0.117891
# min               0.034990             0.036575             0.034914
# 25%               0.348056             0.348451             0.368001
# 50%               0.431071             0.428037             0.446460
# 75%               0.518375             0.504579             0.523162
# max               0.904997             0.980323             0.872131
#
#        chroma_stft_mean_09  ...  mfcc_std_17  mfcc_std_18  mfcc_std_19  \
# count          8000.000000  ...  8000.000000  8000.000000  8000.000000
# mean              0.435047  ...     7.656279     7.526116     7.405727
# std               0.117511  ...     1.690096     1.661831     1.614349
# min               0.020716  ...     3.290497     3.214492     3.175324
# 25%               0.354080  ...     6.571841     6.462480     6.354692
# 50%               0.436708  ...     7.443962     7.327211     7.200722
# 75%               0.514573  ...     8.467715     8.331049     8.176214
# max               0.913757  ...    24.185944    27.268291    24.188486
#
#        mfcc_std_20  rmse_mean_01  rmse_std_01  zcr_mean_01   zcr_std_01  \
# count  8000.000000   8000.000000  8000.000000  8000.000000  8000.000000
# mean      7.339868      4.568130     2.196936     0.050856     0.040383
# std       1.626621      2.484890     1.024323     0.028484     0.025868
# min       3.071528      0.000246     0.000013     0.003490     0.002608
# 25%       6.259094      2.735237     1.433715     0.032412     0.022612
# 50%       7.127139      4.286309     2.075846     0.046102     0.033839
# 75%       8.116510      6.012164     2.820238     0.062770     0.051452
# max      18.515343     21.608154     8.914420     0.629665     0.317725
#
#        spectral_centroid_mean_01  spectral_centroid_std_01
# count                8000.000000               8000.000000
# mean                 1174.792826                604.716981
# std                   501.694070                278.862045
# min                   140.754303                 55.689919
# 25%                   818.932144                401.349785
# 50%                  1125.063171                569.657043
# 75%                  1460.376740                758.050583
# max                  5575.107910               3023.301025
#
# [8 rows x 71 columns]

# %% [markdown]
# # eda

# %%
# plt.figure(figsize=(10, 8))
# sns.histplot(df2['chroma_cens_kurtosis_01'])
# plt.title('Histogram Chroma_cens_kurtosis_01')
# plt.xlim(-4, 20)
# plt.show()

# %%
# histogram tonnetz_std_06
# plt.figure(figsize=(10, 8))
# sns.histplot(df2['tonnetz_std_06'])
# plt.title('Histogram tonnetz_std_06')
# plt.show()

# %% [markdown]
# ## PCA

# %%
from sklearn.decomposition import PCA

# %%
train_mask = df2['split'] == 'training'
test_mask = df2['split'].isin(['test', 'validation'])

# Przygotowanie X (usuwamy kolumny opisowe)
# Upewnij się, że nazwy kolumn do usunięcia zgadzają się z Twoim df
cols_to_drop = ['track_id', 'genre', 'split']

X_train = df2.loc[train_mask].drop(columns=cols_to_drop)
y_train = df2.loc[train_mask, 'genre']

X_test = df2.loc[test_mask].drop(columns=cols_to_drop)
y_test = df2.loc[test_mask, 'genre']
# Sprawdzenie wymiarów
print(f"Trening: {X_train.shape[0]} utworów")
print(f"Test (+Val): {X_test.shape[0]} utworów")
# Out:
# Trening: 6400 utworów
# Test (+Val): 1600 utworów

# %%
X_test.head()
# Out:
#     chroma_stft_mean_01  chroma_stft_mean_02  chroma_stft_mean_03  \
# 5              0.402481             0.396132             0.481231
# 6              0.303923             0.351700             0.395064
# 23             0.402743             0.465515             0.750413
# 28             0.342747             0.370128             0.454081
# 36             0.521449             0.584506             0.536022
#
#     chroma_stft_mean_04  chroma_stft_mean_05  chroma_stft_mean_06  \
# 5              0.468269             0.347547             0.356223
# 6              0.507798             0.394258             0.515136
# 23             0.565675             0.481108             0.437815
# 28             0.419604             0.340761             0.385564
# 36             0.535275             0.559491             0.542604
#
#     chroma_stft_mean_07  chroma_stft_mean_08  chroma_stft_mean_09  \
# 5              0.395001             0.388475             0.436664
# 6              0.408766             0.433628             0.332516
# 23             0.518940             0.525105             0.390097
# 28             0.333869             0.351868             0.377422
# 36             0.537674             0.526300             0.554916
#
#     chroma_stft_mean_10  ...  mfcc_std_17  mfcc_std_18  mfcc_std_19  \
# 5              0.404522  ...     8.310235     9.033209     8.955352
# 6              0.300106  ...     6.382796     6.669587     6.099824
# 23             0.544671  ...     6.403784     6.292244     6.222865
# 28             0.396551  ...     8.070022     7.566155     6.686774
# 36             0.520828  ...     7.742085     6.814579     6.201910
#
#     mfcc_std_20  rmse_mean_01  rmse_std_01  zcr_mean_01  zcr_std_01  \
# 5      6.484027     10.810444     4.051363     0.063609    0.063442
# 6      6.104943      7.483398     1.231706     0.051366    0.018802
# 23     6.007671      8.803668     2.470242     0.033303    0.022909
# 28     6.942421      1.640143     1.271307     0.024282    0.028310
# 36     6.839896      6.684638     2.098298     0.077424    0.033266
#
#     spectral_centroid_mean_01  spectral_centroid_std_01
# 5                 1192.512695                699.388489
# 6                  916.347839                226.025040
# 23                1087.210815                560.997742
# 28                 565.619873                545.910217
# 36                1577.285767                505.484528
#
# [5 rows x 70 columns]

# %%
pca = PCA(n_components=4)
pca.fit(X_train)
X_train_pca = pca.transform(X_train)
X_test_pca = pca.transform(X_test)

# %%
# Skumulowana zmienność
plt.figure(figsize=(8, 5))
sns.barplot(x=np.arange(1,5), y=np.cumsum(pca.explained_variance_ratio_)[:4], color='skyblue')
plt.axhline(y=0.7, color='pink', linestyle='--', label='70% Wariancji')
for i, v in enumerate(np.cumsum(pca.explained_variance_ratio_)[:4]):
    plt.text(i , v + 0.02, f"{v:.2f}", ha='center', va='bottom')
plt.xlabel('Number of components')
plt.ylabel('Cumulative explained variance')
plt.show()

# %%
X_train_pca.shape
# Out:
# (6400, 4)

# %%
# PC1 vs PC2
plt.figure(figsize=(10, 8))
sns.scatterplot(x=X_train_pca[:, 0], y=X_train_pca[:, 1], hue=y_train, palette='Set2')
plt.title('PC1 vs PC2')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend(title='Genre')
plt.show()

# %% [markdown]
# ## Wstępne modelowanie

# %%
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X_train_pca = scaler.fit_transform(X_train_pca)
X_test_pca = scaler.transform(X_test_pca)

# %%
model_svm = SVC(kernel='linear', C=1, random_state=42)
model_svm.fit(X_train_pca, y_train)
y_pred_test_svm = model_svm.predict(X_test_pca)
y_pred_train_svm = model_svm.predict(X_train_pca)
print("SVM Train Accuracy: ", accuracy_score(y_train, y_pred_train_svm))
print("SVM Test Accuracy: ", accuracy_score(y_test, y_pred_test_svm))
# Out:
# SVM Train Accuracy:  0.33125
# SVM Test Accuracy:  0.346875

# %%
model_RF = RandomForestClassifier(n_estimators=500, max_depth=20, min_samples_leaf=2, random_state=42)
model_RF.fit(X_train_pca, y_train)
y_pred_test_RF = model_RF.predict(X_test_pca)
y_pred_train_RF = model_RF.predict(X_train_pca)
print("Random Forest Train Accuracy: ", accuracy_score(y_train, y_pred_train_RF))
print("Random Forest Test Accuracy: ", accuracy_score(y_test, y_pred_test_RF))
# Out:
# Random Forest Train Accuracy:  0.97859375
# Random Forest Test Accuracy:  0.325

# %% [markdown]
# ## Modelowanie bez PCA

# %%
scaler = StandardScaler()
X_train_nopca = scaler.fit_transform(X_train)
X_test_nopca = scaler.transform(X_test)

# %%
X_train_nopca.shape
# Out:
# (6400, 70)

# %%
model_RF = RandomForestClassifier(n_estimators=50, max_depth=5, min_samples_leaf=5, random_state=42)
model_RF.fit(X_train_nopca, y_train)
y_pred_test_RF = model_RF.predict(X_test_nopca)
y_pred_train_RF = model_RF.predict(X_train_nopca)
print("Random Forest Train Accuracy: ", accuracy_score(y_train, y_pred_train_RF))
print("Random Forest Test Accuracy: ", accuracy_score(y_test, y_pred_test_RF))
# Out:
# Random Forest Train Accuracy:  0.508125
# Random Forest Test Accuracy:  0.42875

# %%
model_svm = SVC(kernel='rbf', C=10, gamma='scale', random_state=42)
model_svm.fit(X_train_nopca, y_train)
y_pred_test_svm = model_svm.predict(X_test_nopca)
y_pred_train_svm = model_svm.predict(X_train_nopca)
print("SVM Train Accuracy: ", accuracy_score(y_train, y_pred_train_svm))
print("SVM Test Accuracy: ", accuracy_score(y_test, y_pred_test_svm))
# Out:
# SVM Train Accuracy:  0.97484375
# SVM Test Accuracy:  0.45625

# %%
from sklearn.ensemble import GradientBoostingClassifier
model_GB = GradientBoostingClassifier(
    n_estimators=100,      # Na początek 100 wystarczy, żeby sprawdzić trend
    learning_rate=0.01,     # Standardowy krok uczenia
    max_depth=4,           # BARDZO WAŻNE: Boosting używa płytkich drzew (tzw. stumps)
    subsample=0.8,         # Uczymy na 80% danych (dodaje element losowości, chroni przed overfittingiem)
    random_state=42,
)

model_GB.fit(X_train_nopca, y_train)

y_pred_train_GB = model_GB.predict(X_train_nopca)
y_pred_test_GB = model_GB.predict(X_test_nopca)

print(f"GB Train Accuracy: {accuracy_score(y_train, y_pred_train_GB):.4f}")
print(f"GB Test Accuracy: {accuracy_score(y_test, y_pred_test_GB):.4f}")
# Out:
# GB Train Accuracy: 0.6069
# GB Test Accuracy: 0.4281
